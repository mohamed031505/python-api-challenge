# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

import matplotlib.pyplot as plt
import requests
import pandas as pd
#from config import api_key

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 617

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set up lists to hold reponse info
lat = []
lng = []
temp_max = []
humidity = []
cloudness = [] 
wind_speed = []
country = []
date = []
temp = []
cities_found = []

for city in cities:
    
    
    response = requests.get(query_url + city).json()
#     print(response)
    try:
        
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        cities_found.append(city)
        print(" Found City : " + city)
        
    except:
        
        print("Couldn't find : " + city)
# Out:
#  Found City : mataura
#  Found City : hermanus
#  Found City : halifax
#  Found City : yar-sale
#  Found City : jamestown
#  Found City : xinzhi
#  Found City : hithadhoo
#  Found City : springbok
#  Found City : kosino
#  Found City : ballina
#  Found City : taman
# Couldn't find : cam pha
#  Found City : plouzane
#  Found City : puerto escondido
#  Found City : bredasdorp
#  Found City : sao filipe
#  Found City : belyy yar
#  Found City : saskylakh
#  Found City : ushuaia
#  Found City : chokurdakh
#  Found City : hobart
#  Found City : puerto ayora
#  Found City : nikolskoye
#  Found City : thompson
#  Found City : victoria
#  Found City : castro
#  Found City : punta arenas
#  Found City : shimoda
#  Found City : coquimbo
#  Found City : yarada
#  Found City : sistranda
#  Found City : saldanha
#  Found City : albany
#  Found City : dikson
#  Found City : roebourne
#  Found City : rikitea
#  Found City : sterling
#  Found City : touros
# Couldn't find : cazaje
#  Found City : tilichiki
#  Found City : ahipara
# Couldn't find : taolanaro
# Couldn't find : tsihombe
#  Found City : saint-philippe
#  Found City : arandis
#  Found City : pedra branca
#  Found City : khatanga
#  Found City : tahoua
#  Found City : zhelyabovka
#  Found City : nuevo progreso
#  Found City : tall kayf
#  Found City : hasaki
#  Found City : namibe
# Couldn't find : warqla
#  Found City : avarua
#  Found City : cape town
#  Found City : sioux lookout
# Couldn't find : nizhneyansk
#  Found City : carnarvon
#  Found City : cidreira
# Couldn't find : illoqqortoormiut
#  Found City : kovernino
#  Found City : miranda
#  Found City : bonfim
#  Found City : srandakan
# Couldn't find : barentsburg
#  Found City : longyearbyen
#  Found City : pokosnoye
#  Found City : port alfred
#  Found City : busselton
#  Found City : bluff
#  Found City : tasiilaq
#  Found City : kapaa
#  Found City : tuktoyaktuk
#  Found City : chuy
#  Found City : havoysund
#  Found City : vaini
#  Found City : farafangana
# Couldn't find : belushya guba
#  Found City : xingyi
# Couldn't find : mys shmidta
#  Found City : aksarka
#  Found City : kurilsk
#  Found City : hanna
#  Found City : lorengau
#  Found City : umm lajj
#  Found City : swift current
#  Found City : kirakira
#  Found City : anadyr
#  Found City : bengkulu
# Couldn't find : amderma
#  Found City : sept-iles
#  Found City : cabedelo
#  Found City : lavrentiya
#  Found City : lagoa
#  Found City : ostrovnoy
#  Found City : walvis bay
#  Found City : tessalit
#  Found City : airai
#  Found City : ilulissat
# Couldn't find : marcona
#  Found City : lata
#  Found City : geraldton
#  Found City : smithers
#  Found City : tanah merah
#  Found City : ketchikan
#  Found City : kruisfontein
#  Found City : talnakh
#  Found City : hilo
#  Found City : akdepe
#  Found City : lompoc
#  Found City : upernavik
#  Found City : biak
#  Found City : yellowknife
# Couldn't find : tumannyy
#  Found City : den helder
#  Found City : jieshi
#  Found City : atuona
#  Found City : talara
#  Found City : vestmannaeyjar
# Couldn't find : satitoa
# Couldn't find : juifang
# Couldn't find : vaitupu
#  Found City : reserva
#  Found City : luderitz
#  Found City : ambon
#  Found City : port blair
#  Found City : santa maria
#  Found City : barrow
#  Found City : olinda
#  Found City : sobolevo
# Couldn't find : phnum penh
# Couldn't find : karamea
#  Found City : pevek
#  Found City : aklavik
#  Found City : mahon
#  Found City : iguape
#  Found City : roald
#  Found City : ribeira grande
#  Found City : kassala
#  Found City : vila franca do campo
#  Found City : grindavik
#  Found City : bubaque
#  Found City : kuzino
#  Found City : hobyo
#  Found City : ginir
#  Found City : svetlogorsk
#  Found City : singapore
#  Found City : victor harbor
#  Found City : ola
#  Found City : arraial do cabo
# Couldn't find : lolua
#  Found City : kurumkan
# Couldn't find : samusu
#  Found City : lucapa
#  Found City : ryotsu
#  Found City : guaranda
#  Found City : tipuani
#  Found City : emboscada
#  Found City : east london
#  Found City : gat
#  Found City : portland
#  Found City : husavik
#  Found City : kamaishi
#  Found City : cabo san lucas
#  Found City : klaksvik
#  Found City : kasongo-lunda
#  Found City : imst
#  Found City : bacolod
#  Found City : nome
#  Found City : leningradskiy
#  Found City : mar del plata
#  Found City : itanhem
#  Found City : yulara
#  Found City : novyy urengoy
#  Found City : adrar
#  Found City : georgetown
#  Found City : belfast
#  Found City : makakilo city
#  Found City : lac du bonnet
#  Found City : krasnoarmeyskoye
#  Found City : lebu
# Couldn't find : malwan
#  Found City : broome
#  Found City : bethel
#  Found City : marawi
#  Found City : fairbanks
# Couldn't find : sentyabrskiy
#  Found City : hualmay
#  Found City : new norfolk
#  Found City : fort william
#  Found City : rio grande
#  Found City : constitucion
#  Found City : staryy oskol
#  Found City : tres de maio
#  Found City : torbay
#  Found City : gurupa
#  Found City : hami
# Couldn't find : bolungarvik
#  Found City : souillac
#  Found City : paamiut
#  Found City : innisfail
# Couldn't find : attawapiskat
#  Found City : qaanaaq
#  Found City : beloha
#  Found City : mizan teferi
#  Found City : kaitangata
# Couldn't find : mutsamudu
#  Found City : malanje
#  Found City : korla
#  Found City : los llanos de aridane
#  Found City : san patricio
#  Found City : la ronge
#  Found City : chateaudun
#  Found City : marsa matruh
#  Found City : petropavlovsk-kamchatskiy
#  Found City : oistins
# Couldn't find : formoso do araguaia
#  Found City : katsuura
#  Found City : haines junction
#  Found City : klyuchi
#  Found City : cecina
#  Found City : wajir
#  Found City : faya
#  Found City : kwinana
#  Found City : mana
#  Found City : puerto ayacucho
#  Found City : ponta delgada
#  Found City : salas
#  Found City : cherskiy
#  Found City : champerico
#  Found City : severo-kurilsk
#  Found City : tiksi
#  Found City : itupiranga
#  Found City : tezu
#  Found City : clyde river
#  Found City : ucar
#  Found City : orlik
#  Found City : butaritari
#  Found City : grand gaube
#  Found City : bilibino
#  Found City : san cristobal
#  Found City : kavieng
#  Found City : valle de allende
#  Found City : hamilton
#  Found City : zonguldak
#  Found City : itarema
#  Found City : quatre cocos
#  Found City : guerrero negro
#  Found City : seminole
#  Found City : waingapu
#  Found City : amalapuram
#  Found City : isla mujeres
#  Found City : surt
#  Found City : whitehorse
#  Found City : iqaluit
#  Found City : myrtle beach
#  Found City : pishin
#  Found City : bolshoye selo
#  Found City : ormara
#  Found City : ambovombe
#  Found City : filimonovo
#  Found City : klobuck
#  Found City : nha trang
#  Found City : novo aripuana
#  Found City : mackay
#  Found City : tabou
# Couldn't find : louisbourg
#  Found City : shelburne
#  Found City : forbes
# Couldn't find : san ignacio de sabaneta
#  Found City : douglas
#  Found City : riverton
#  Found City : kampene
#  Found City : otukpo
#  Found City : soe
#  Found City : port moresby
#  Found City : severo-yeniseyskiy
#  Found City : iracemapolis
#  Found City : luunja
#  Found City : fereydun kenar
#  Found City : rosario oeste
# Couldn't find : palabuhanratu
#  Found City : kloulklubed
# Couldn't find : umm jarr
#  Found City : machali
#  Found City : port lincoln
#  Found City : atar
#  Found City : tautira
#  Found City : mago
#  Found City : mufumbwe
# Couldn't find : karaul
#  Found City : piacabucu
#  Found City : tooele
#  Found City : rabaul
#  Found City : pochutla
#  Found City : nanakuli
#  Found City : cookeville
#  Found City : andros town
#  Found City : mantua
#  Found City : verkh-usugli
#  Found City : buchanan
# Couldn't find : kokkinion
#  Found City : stolin
#  Found City : garissa
#  Found City : arona
#  Found City : dryden
#  Found City : ponta do sol
#  Found City : ecully
#  Found City : mirpur khas
#  Found City : severobaykalsk
#  Found City : gleisdorf
#  Found City : agirish
#  Found City : umm bab
#  Found City : niquero
#  Found City : erenhot
#  Found City : barra patuca
#  Found City : tuyen quang
#  Found City : perth
# Couldn't find : galiwinku
#  Found City : blumenau
#  Found City : kenai
#  Found City : pangkalanbuun
#  Found City : zeya
#  Found City : tobol
#  Found City : affery
#  Found City : kaeo
#  Found City : sosnovka
# Couldn't find : ngukurr
#  Found City : fabriano
#  Found City : tashigang
#  Found City : pangnirtung
#  Found City : haldia
#  Found City : maraa
#  Found City : manggar
#  Found City : shingu
#  Found City : loukhi
#  Found City : skibbereen
#  Found City : marystown
# Couldn't find : saleaula
#  Found City : kahului
#  Found City : zhangye
#  Found City : zharkent

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({"City": cities_found,
                           "Lat" : lat,
                           "Lng" : lng,
                           "Max Temp" : temp_max,
                           "Humidity" : humidity,
                           "Cloudiness" : cloudness,
                           "Wind Speed" : wind_speed,
                           "Country" : country,
                           "Date" : date})

weather_df.head()

weather_df.to_csv("../starter_code/Resources/weather_city_data.csv", index = False)

# %%
weather_statistics = weather_df.describe()

weather_statistics
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  568.000000  568.000000  568.000000  568.000000  568.000000  568.000000
# mean    18.689511   17.569183   11.791585   74.255282   49.294014    3.613327
# std     32.773093   91.012653   17.133392   21.194904   40.310521    2.570847
# min    -54.800000 -179.166700  -37.880000    1.000000    0.000000    0.150000
# 25%     -8.042925  -58.848175    2.367500   65.000000    1.000000    1.570000
# 50%     20.839000   17.587150   17.400000   80.000000   49.500000    3.090000
# 75%     45.954375  100.602175   24.750000   90.000000   90.000000    5.037500
# max     78.218600  179.316700   39.000000  100.000000  100.000000   16.390000
#
#                Date
# count  5.680000e+02
# mean   1.614488e+09
# std    8.705477e+01
# min    1.614487e+09
# 25%    1.614488e+09
# 50%    1.614488e+09
# 75%    1.614488e+09
# max    1.614488e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_humidity_grt100 = weather_df.loc[weather_df['Humidity'] > 100]

city_humidity_grt100.head()
if len(city_humidity_grt100['City']) == 0:
    print(" No City Found Where Humidity is greater than 100% ")
else:
    city_humidity_grt100.head()
# Out:
#  No City Found Where Humidity is greater than 100%

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
clean_city_data_df = weather_df.loc[weather_df['Humidity'] <= 100]

clean_city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    mataura -46.1927  168.8643     20.00        80          85        2.24
# 1   hermanus -34.4187   19.2345     21.11        80          79        5.36
# 2    halifax  44.6453  -63.5724      5.00       100         100        9.77
# 3   yar-sale  66.8333   70.8333    -25.69        89           9        4.85
# 4  jamestown  42.0970  -79.2353     -1.11        95           1        1.59
#
#   Country        Date
# 0      NZ  1614487863
# 1      ZA  1614487863
# 2      CA  1614487806
# 3      RU  1614487864
# 4      US  1614487764

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_axis = clean_city_data_df['Lat']
data = clean_city_data_df['Max Temp']

plt.scatter(x_axis, data, marker="o", facecolors="blue", edgecolors="black",
            s=x_axis, alpha=0.75)
plt.xlim(-60, 100)
plt.xlabel("Latitude")
plt.ylabel("Max. Temperature")
plt.title = "City Latitude vs. Max. Temperature"
# plt.xtitle("")
plt.show()
# Out:
# /Users/mohammedelfashni/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/matplotlib/collections.py:885: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_axis = clean_city_data_df['Lat']
data = clean_city_data_df['Humidity']

plt.scatter(x_axis, data, marker="o", facecolors="blue", edgecolors="black",
            s=x_axis, alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
# plt.title("City Latitude vs. Humidity")
plt.xlim(-60, 100)
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_axis = clean_city_data_df['Lat']
data = clean_city_data_df['Cloudiness']

plt.scatter(x_axis, data, marker="o", facecolors="blue", edgecolors="black",
            s=x_axis, alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
# plt.title("City Latitude vs. Cloudiness")
plt.xlim(-60, 100)
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_axis = clean_city_data_df['Lat']
data = clean_city_data_df['Wind Speed']

plt.scatter(x_axis, data, marker="o", facecolors="blue", edgecolors="black",
            s=x_axis, alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
# plt.title("City Latitude vs. Speed")
plt.xlim(-60, 100)
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
x_values = clean_city_data_df['Lat']
y_values = clean_city_data_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max. Temp')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#take the data frame and call it northo_df[lat] > 0 .loc to get the northen and <0 for southern hemispherer datafram 

northern_df = clean_city_data_df.loc[clean_city_data_df['Lat'] > 0]
x_values = northern_df['Lat']
y_values = northern_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp ')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7664128411724193

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
southern_df = clean_city_data_df.loc[clean_city_data_df['Lat'] < 0]
x_values = southern_df['Lat']
y_values = southern_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp ')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.08297492569613625

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_df['Lat']
y_values = northern_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.15220279538221085

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_df['Lat']
y_values = southern_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.07664256728849692

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_df['Lat']
y_values = northern_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness ')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.07256935210451715

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_df['Lat']
y_values = southern_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.08140059476674598

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_df['Lat']
y_values = northern_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.009341592865714317

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_df['Lat']
y_values = southern_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed ')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.14510060028778962
