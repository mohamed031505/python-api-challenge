# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
weather_df = pd.read_csv('Resources/weather_city_data.csv')

weather_df
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       mataura -46.1927  168.8643     20.00        80          85
# 1      hermanus -34.4187   19.2345     21.11        80          79
# 2       halifax  44.6453  -63.5724      5.00       100         100
# 3      yar-sale  66.8333   70.8333    -25.69        89           9
# 4     jamestown  42.0970  -79.2353     -1.11        95           1
# ..          ...      ...       ...       ...       ...         ...
# 563  skibbereen  51.5500   -9.2667      2.00        93          75
# 564   marystown  47.1666  -55.1483     -3.77        94          34
# 565     kahului  20.8947 -156.4700     24.00        64           1
# 566     zhangye  38.9342  100.4517     -2.26        58         100
# 567    zharkent  44.1628   80.0000     -1.38        45          15
#
#      Wind Speed Country        Date
# 0          2.24      NZ  1614487863
# 1          5.36      ZA  1614487863
# 2          9.77      CA  1614487806
# ...

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
locations = weather_df[["Lat", "Lng"]]
weights = weather_df["Humidity"]

# %%
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=weights, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)

fig.add_layer(heat_layer)


fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#Max Temp is metric units


ideal_weather_df = weather_df.loc[(weather_df['Max Temp'] < 30) & (weather_df['Max Temp'] > 18)& (weather_df['Wind Speed'] < 10)& (weather_df['Cloudiness'] == 0)]


# ideal_weather_df.reset_index(drop=True)

hotel_df = ideal_weather_df.dropna()

hotel_df.reset_index(drop=True)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          springbok -29.6643   17.8865     18.28        43           0
# 1   puerto escondido  15.8500  -97.0667     24.59        70           0
# 2         sao filipe  14.8961  -24.4956     19.43        75           0
# 3     saint-philippe -21.3585   55.7679     29.00        61           0
# 4             namibe -15.1961   12.1522     19.92        82           0
# 5          cape town -33.9258   18.4232     21.11        77           0
# 6               chuy -33.6971  -53.4616     20.57        78           0
# 7           umm lajj  25.0213   37.2685     21.53        54           0
# 8        santa maria -29.6842  -53.8069     19.32        78           0
# 9              ginir   7.1333   40.7000     18.38        39           0
# 10         emboscada -25.1500  -57.3500     25.00        78           0
# 11       east london -33.0153   27.9116     19.00        94           0
# ...

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df['Hotel Name'] = ""

hotel_df
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 7           springbok -29.6643   17.8865     18.28        43           0
# 12   puerto escondido  15.8500  -97.0667     24.59        70           0
# 14         sao filipe  14.8961  -24.4956     19.43        75           0
# 39     saint-philippe -21.3585   55.7679     29.00        61           0
# 48             namibe -15.1961   12.1522     19.92        82           0
# 50          cape town -33.9258   18.4232     21.11        77           0
# 66               chuy -33.6971  -53.4616     20.57        78           0
# 75           umm lajj  25.0213   37.2685     21.53        54           0
# 111       santa maria -29.6842  -53.8069     19.32        78           0
# 127             ginir   7.1333   40.7000     18.38        39           0
# 138         emboscada -25.1500  -57.3500     25.00        78           0
# 139       east london -33.0153   27.9116     19.00        94           0
# ...

# %%
params = {
    "radius": 50000,
    "types": "lodging",
    "key": g_key
}


for index, row in hotel_df.iterrows():
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lng"]

  
    params["location"] = f"{lat},{lng}"

    
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

  
    name_address = requests.get(base_url, params=params)
    



    name_address = name_address.json()
   
    try:
        x = hotel_df.loc[index, "Hotel Name"] = name_address["results"][0]["name"]
        print(x)

    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
hotel_df.head()
# Out:
# Biesjesfontein B&B
# Aldea del Bazar Hotel and Spa
# Tortuga B&B
# Hôtel L'Ecrin
# Hotel Chik Chik Namibe
# Southern Sun Waterfront Cape Town
# La Casa de las Boyas
# Moon light Furnished Units
# Hotel Morotin
# Sura Dare Village
# La Misión Hotel Boutique
# Tu Casa
# Sênior Parque Hotel
# Al-bustan Hotel And Restaurant.
# Sur Plaza Hotel
# Complejo San Fructuoso
# Missing field/result... skipping.
# Sama Emirate Hotel
# Punta del Este Resort & Spa
# Quartier Paoua Elien
# Hôtel Le Cilaos
# HS Hotsson Smart Acapulco
# True Treasure Hotel
# Ethos Inn
# Missing field/result... skipping.
# Hotel Morón
# Luxury Resort near Jodhpur, Desert Dunes Camp Tent in Jaisalmer | Thar Oasis Resort and Camp
# Hôtel de l'UCom CVPC
# Phoenix Hotel
# Manaus Hotéis Millennium
# Crystal Beach and Camping Resort Ormara
# Hotel Mar Andino
# La Isla Huatulco
# Hotel Al-Fajar
# Beatty Lodge
#                 City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# ...

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
markers = gmaps.marker_layer(locations)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
